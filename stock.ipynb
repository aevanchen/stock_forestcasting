# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
n_days=3;
df1=pd.read_csv('DJIA_table.csv')
df2 = df1.set_index("Date")
df3=df2["Adj Close"]
df_1=pd.DataFrame(df3)
df_1=df_1.rename(columns={'Adj Close': 'DJIA'})

df_1=df_1.sort_index(ascending=True)

df_sub = pd.concat([df_1], axis=1)


df_1["DJIA_1"] = ''
df_1["DJIA_2"] = ''
df_1["DJIA_3"] = ''


df=df_1
df_1=df_1.iloc[n_days:,:]

for index in range (0,df_1.shape[0]):
    df_1.iat[index,1]=df.iloc[index,0]
    df_1.iat[index,2]=df.iloc[index+1,0]
    df_1.iat[index,3]=df.iloc[index+2,0]

df_prices=df_1
df_prcies=pd.DataFrame(df_prices)

# %%
##df is the processed input data, the first colomn is the target prices; 
##the 2-4 colomns are the prices before the targeting day (1,2,3days before)

df_news=pd.read_csv('RedditNews.csv')

df1=pd.read_csv('Combined_News_DJIA.csv')
df2 = df1.set_index("Date")

del df2['Label']
df_news2=df2
df_news2=df_news2.iloc[3:,:]
df_1=pd.DataFrame(df2)
df_1=df_1.sort_index(ascending=True)
for i in range (26,101):
    df_1["Top%d"%i]=''

df=df_1
df_1=df_1.iloc[n_days:,:]

for index in range (0,df_1.shape[0]):
    for i in range (0,25):
        df_1.iat[index,25+i]=df.iloc[index,i]
        df_1.iat[index,50+i]=df.iloc[index+1,i]
        df_1.iat[index,75+i]=df.iloc[index+2,i]
df_news=df_1
df_news=pd.DataFrame(df_news)
df_news
# Out:
#                                                          Top1  \
# Date
# 2008-08-13  b' U.S. refuses Israel weapons to attack Iran:...
# 2008-08-14  b'All the experts admit that we should legalis...
# 2008-08-15  b"Mom of missing gay man: Too bad he's not a 2...
# 2008-08-18  b'In an Afghan prison, the majority of female ...
# 2008-08-19  b"Man arrested and locked up for five hours af...
# 2008-08-20  b'Two elderly Chinese women have been sentence...
# 2008-08-21  b"British resident held in Guantanamo Bay wins...
# 2008-08-22  b'Syria says its ready to put a Russian missil...
# 2008-08-25  b"N Korea's Kim died in 2003; replaced by look...
# 2008-08-26  b'North Korea halts denuclearisation after US ...
# 2008-08-27  b'Photos of a 15-year-old Iraqi suicide bomber...
# 2008-08-28  b"Military help for Georgia is a 'declaration ...
# 2008-08-29  b'Russian Prime Minister Vladimir Putin has ac...
# 2008-09-02  b"A girl filmed Israeli soldiers' brutality. S...
# ...

# %%
#top 10 news##################################
n=5
df_news=pd.read_csv('RedditNews.csv')

df1=pd.read_csv('Combined_News_DJIA.csv')
df2 = df1.set_index("Date")

del df2['Label']
df_news2=df2
df_news2=df_news2.iloc[3:,:]
df_1=pd.DataFrame(df2)
df_1=df_1.sort_index(ascending=True)
df_1=df_1.iloc[:,:5]
df_1
for i in range (6,21):
    df_1["Top%d"%i]=''

df=df_1
df_1
for i in range (6,21):
    df_1["Top%d"%i]=''

df=df_1
df_1=df_1.iloc[n_days:,:]

for index in range (0,df_1.shape[0]):
    for i in range (0,5):
        df_1.iat[index,5+i]=df.iloc[index,i]
        df_1.iat[index,10+i]=df.iloc[index+1,i]
        df_1.iat[index,15+i]=df.iloc[index+2,i]
df_news3=df_1

# %%
###################
df= pd.concat([df_prices,df_news], axis=1)
for i in range (1,101):
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: repr(x).replace('b',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\"',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\'',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('.',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\\',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.strip())
df['news']=""
df['news']=df[['news','Top26']].apply(lambda x: ''.join(x), axis=1)
for i in range (27,101):
    df['news']=df[['news','Top%d'%i]].apply(lambda x: '. '.join(x), axis=1)
df['news']=df['news']+"."
df1=df.iloc[:,[0,1,2,3,104]]

# %%
df= pd.concat([df_prices,df_news2], axis=1)
for i in range (1,26):
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: repr(x).replace('b',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\"',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\'',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('.',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\\',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.strip())
df['news']=""
df['news']=df[['news','Top1']].apply(lambda x: ''.join(x), axis=1)
for i in range (2,26):
    df['news']=df[['news','Top%d'%i]].apply(lambda x: '. '.join(x), axis=1)
df['news']=df['news']+"."
df2=df.iloc[:,[0,1,2,3,29]]

# %%
df= pd.concat([df_prices,df_news3], axis=1)
for i in range (1,21):
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: repr(x).replace('b',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\"',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\'',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('.',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.replace('\\',''))
    df['Top%d'%i]=df['Top%d'%i].map(lambda x: x.strip())
df['news']=""
df['news']=df[['news','Top1']].apply(lambda x: ''.join(x), axis=1)
for i in range (7,21):
    df['news']=df[['news','Top%d'%i]].apply(lambda x: '. '.join(x), axis=1)
df['news']=df['news']+"."
df3=df.iloc[:,[0,1,2,3,24]]

# %%
#trainx are the training data, trainy are the label for training
#testx,y are similar to above format, which are data for testing
df=df3
#df=df2

df_news=df

df_news["compound"] = ''
df_news["neg"] = ''
df_news["neu"] = ''
df_news["pos"] = ''

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import unicodedata
sid = SentimentIntensityAnalyzer()
a=0
for i in range (0,1986):
    try:
        ss = sid.polarity_scores(df_news.iloc[i,4])
        
        print(ss)
        df.iat[a, 5]= ss['compound']
        df.iat[a, 6]= ss['neg']
        df.iat[a, 7]= ss['neu']
        df.iat[a, 8]= ss['pos']
        a=a+1
    except TypeError:
        print (df_stocks.loc[date, 'news'])
        print (Date)

# %%
a=df_news[['DJIA','DJIA_1','DJIA_2','DJIA_3','neg','pos']]
#trainx are the training data, trainy are the label for training
#testx,y are similar to above format, which are data for testing
df=a
#df=df2
split=0.8
row=round(split*df_sub.shape[0])

df_sub=np.array(df_sub,dtype=float)
#df_sub=df_sub[:row,:]
MAX=np.max(df_sub,axis=0)


data=np.array(df)

#normalization
data[:,0:4]=data[:,0:4]/MAX[0]

row=round(split*data.shape[0])
train=data[:row,:]
test=data[row:,:]

#shuffle the training data
np.random.shuffle(train)
#format traning data nad testing data
train_y=train[:,[0]]
train_x=train[:,[1,2,3,4,5]]  
test_y=test[:,[0]]
test_x=test[:,[1,2,3,4,5]]
print("ok")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-0ea71eac5d6f> in <module>()
#       1
# ----> 2 a=df_news[['DJIA','DJIA_1','DJIA_2','DJIA_3','neg','pos']]
#       3 #trainx are the training data, trainy are the label for training
#       4 #testx,y are similar to above format, which are data for testing
#       5 df=a
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
# ...

# %%
train_x
# Out:
# array([[0.57146715042837293, 0.57154964877776582, 0.57447932710860905,
#         0.166, 0.083],
#        [0.62705632629546415, 0.62285312287018779, 0.62308685931059316,
#         0.177, 0.056],
#        [0.73760551468140167, 0.73911101642415944, 0.73781903988846353,
#         0.148, 0.069],
#        ...,
#        [0.59251468441193755, 0.5949993408902613, 0.59563058397789059,
#         0.182, 0.056],
#        [0.68719427079171969, 0.69017423736831196, 0.69268289147802076,
#         0.164, 0.08],
#        [0.83566913366888718, 0.84147340254762604, 0.8356527620216162,
#         0.149, 0.059]], dtype=object)

# %%
T1=pd.DataFrame(train_x)
T2=pd.DataFrame(train_y)
T3=pd.DataFrame(test_x)
T4=pd.DataFrame(test_y)
T1.to_csv("Xtrain.csv",header=False,index=False)
T2.to_csv("Ytrain.csv",header=False,index=False)
T3.to_csv("Xtest.csv",header=False,index=False)
T4.to_csv("Ytest.csv",header=False,index=False)

# %%
abc=pd.DataFrame(data)
abc.to_csv("generated_news_data.csv",header=False,index=False)

# %%
df=df1
#df=df2
split=0.8


data=np.array(df)

row=round(split*data.shape[0])
train=data[:row,:]
test=data[row:,:]

#shuffle the training data
np.random.shuffle(train)
#format traning data nad testing data
train_y=train[:,[0]]
train_x=train[:,[1,2,3,4,5]]  
test_y=test[:,[0]]
test_x=test[:,[1,2,3,4,5]]
print("ok")
# Out:
# ok

# %%
import keras.backend as K
from sklearn.metrics import r2_score


#model1, 3days of previous prices and 3 days of previous news to predict the following day's price
from keras.layers.core import Dense, Activation, Dropout
from keras.models import Sequential
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau
import time #helper libraries
import matplotlib.pyplot as plt
model1 = Sequential()
model1.add(Dense(32, input_dim=5, kernel_initializer='normal', activation='relu'))


model1.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))

start = time.time()

#optimizer = optimizers.Adam(lr=0.001, decay=0.0)

model1.compile(loss='mse', optimizer='adam')
print ('compilation time : ', time.time() - start)


#callbacks=[learning_rate_reduction]
model1.fit(
    train_x,
    train_y,
    batch_size=1,
    nb_epoch=2000,
    verbose=1,
    validation_split=0.1)
# Out:
# compilation time :  0.027008056640625
# C:\Users\pc\Anaconda3\lib\site-packages\keras\models.py:848: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 1430 samples, validate on 159 samples
# Epoch 1/2000
# 1430/1430 [==============================] - 1s - loss: 0.0144 - val_loss: 0.0107
# Epoch 2/2000
# 1430/1430 [==============================] - 0s - loss: 0.0045 - val_loss: 0.0015
# Epoch 3/2000
# 1430/1430 [==============================] - 0s - loss: 7.7189e-04 - val_loss: 5.7966e-04
# Epoch 4/2000
# 1430/1430 [==============================] - 0s - loss: 4.3243e-04 - val_loss: 3.5347e-04
# Epoch 5/2000
# 1430/1430 [==============================] - 0s - loss: 2.6230e-04 - val_loss: 2.3019e-04
# Epoch 6/2000
# 1430/1430 [==============================] - 0s - loss: 1.8238e-04 - val_loss: 1.8576e-04
# Epoch 7/2000
# ...

# %%
# returns a compiled model

def plot_results(predicted_data, true_data):
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    plt.plot(predicted_data, label='Prediction')
    plt.legend()
    plt.show()
import lstm
predictions = lstm.predict_point_by_point(model1, test_x)


plot_results(predictions,test_y)
from sklearn.metrics import r2_score
r2_score(test_y, predictions)
# Out:
# 0.90746490108379607

# %%
a=0.8831289012354213312

a
# Out:
# 0.8831289012354213

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import unicodedata
sid = SentimentIntensityAnalyzer()
a=0
for i in range (0,1986):
    try:
        ss = sid.polarity_scores(df_news.iloc[i,4])
        
        print(ss)
        df.iat[a, 5]= ss['compound']
        df.iat[a, 6]= ss['neg']
        df.iat[a, 7]= ss['neu']
        df.iat[a, 8]= ss['pos']
        a=a+1
    except TypeError:
        print (df_stocks.loc[date, 'news'])
        print (Date)
# Out:
# {'neg': 0.152, 'neu': 0.792, 'pos': 0.056, 'compound': -0.9859}
# {'neg': 0.193, 'neu': 0.714, 'pos': 0.093, 'compound': -0.9876}
# {'neg': 0.164, 'neu': 0.752, 'pos': 0.084, 'compound': -0.9745}
# {'neg': 0.223, 'neu': 0.72, 'pos': 0.058, 'compound': -0.9933}
# {'neg': 0.201, 'neu': 0.755, 'pos': 0.044, 'compound': -0.9942}
# {'neg': 0.184, 'neu': 0.766, 'pos': 0.05, 'compound': -0.9919}
# {'neg': 0.216, 'neu': 0.717, 'pos': 0.067, 'compound': -0.9963}
# {'neg': 0.134, 'neu': 0.776, 'pos': 0.09, 'compound': -0.9449}
# {'neg': 0.279, 'neu': 0.703, 'pos': 0.018, 'compound': -0.9978}
# {'neg': 0.279, 'neu': 0.639, 'pos': 0.083, 'compound': -0.9966}
# {'neg': 0.182, 'neu': 0.768, 'pos': 0.05, 'compound': -0.9912}
# {'neg': 0.152, 'neu': 0.736, 'pos': 0.112, 'compound': -0.9169}
# {'neg': 0.118, 'neu': 0.802, 'pos': 0.08, 'compound': -0.9053}
# {'neg': 0.241, 'neu': 0.713, 'pos': 0.046, 'compound': -0.9968}
# {'neg': 0.161, 'neu': 0.777, 'pos': 0.062, 'compound': -0.9844}
# ...

# %%
df_news
# Out:
#                     DJIA   DJIA_1   DJIA_2   DJIA_3  \
# Date
# 2008-08-13  11532.959961  11734.3  11782.3  11642.5
# 2008-08-14  11615.929688  11782.3  11642.5    11533
# 2008-08-15  11659.900391  11642.5    11533  11615.9
# 2008-08-18  11479.389648    11533  11615.9  11659.9
# 2008-08-19  11348.549805  11615.9  11659.9  11479.4
# 2008-08-20  11417.429688  11659.9  11479.4  11348.5
# 2008-08-21  11430.209961  11479.4  11348.5  11417.4
# 2008-08-22  11628.059570  11348.5  11417.4  11430.2
# 2008-08-25  11386.250000  11417.4  11430.2  11628.1
# 2008-08-26  11412.870117  11430.2  11628.1  11386.2
# 2008-08-27  11502.509766  11628.1  11386.2  11412.9
# 2008-08-28  11715.179688  11386.2  11412.9  11502.5
# 2008-08-29  11543.959961  11412.9  11502.5  11715.2
# 2008-09-02  11516.919922  11502.5  11715.2    11544
# 2008-09-03  11532.879883  11715.2    11544  11516.9
# 2008-09-04  11188.230469    11544  11516.9  11532.9
# 2008-09-05  11220.959961  11516.9  11532.9  11188.2
# ...

# %%
a=df_news[['DJIA','DJIA_1','DJIA_2','DJIA_3','neg','neg']]
#trainx are the training data, trainy are the label for training
#testx,y are similar to above format, which are data for testing
df=a
#df=df2
split=0.8
row=round(split*df_sub.shape[0])

df_sub=np.array(df_sub,dtype=float)
#df_sub=df_sub[:row,:]
MAX=np.max(df_sub,axis=0)


data=np.array(df)

#normalization
data[:,0:4]=data[:,0:4]/MAX[0]

row=round(split*data.shape[0])
train=data[:row,:]
test=data[row:,:]

#shuffle the training data
np.random.shuffle(train)
#format traning data nad testing data
train_y=train[:,[0]]
train_x=train[:,[1,2,3,4,5]]  
test_y=test[:,[0]]
test_x=test[:,[1,2,3,4,5]]

# %%
model2 = Sequential()
model2.add(Dense(64, input_dim=5, kernel_initializer='normal', activation='relu'))

model2.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))

start = time.time()
sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0, nesterov=False)
model2.compile(loss='mse', optimizer='adam')
print ('compilation time : ', time.time() - start)

model2.fit(
    train_x,
    train_y,
    batch_size=32,
    nb_epoch=1000,
    validation_split=0.05)

predictions = lstm.predict_point_by_point(model2, test_x)


plot_results(predictions,test_y)
from sklearn.metrics import r2_score
r2_score(test_y, predictions)
# Out:
# compilation time :  0.04101085662841797
# Train on 1509 samples, validate on 80 samples
# Epoch 1/1000
# 1509/1509 [==============================] - 0s - loss: 0.0387 - val_loss: 0.0275
# Epoch 2/1000
# 1509/1509 [==============================] - 0s - loss: 0.0172 - val_loss: 0.0174
# Epoch 3/1000
# 1509/1509 [==============================] - 0s - loss: 0.0146 - val_loss: 0.0163
# Epoch 4/1000
# 1509/1509 [==============================] - 0s - loss: 0.0135 - val_loss: 0.0148
# Epoch 5/1000
# 1509/1509 [==============================] - 0s - loss: 0.0121 - val_loss: 0.0128
# Epoch 6/1000
# 1509/1509 [==============================] - 0s - loss: 0.0103 - val_loss: 0.0106
# Epoch 7/1000
# 1509/1509 [==============================] - 0s - loss: 0.0085 - val_loss: 0.0085
# Epoch 8/1000
# 1509/1509 [==============================] - 0s - loss: 0.0066 - val_loss: 0.0063
# Epoch 9/1000
# 1509/1509 [==============================] - 0s - loss: 0.0050 - val_loss: 0.0045
# Epoch 10/1000
# ...

# %%
#model 3
df=a
#df=df2
split=0.8
row=round(split*df_sub.shape[0])

df_sub=np.array(df_sub,dtype=float)
#df_sub=df_sub[:row,:]
MAX=np.max(df_sub,axis=0)


data=np.array(df)

#normalization
data[:,0:4]=data[:,0:4]/MAX[0]

row=round(split*data.shape[0])
train=data[:row,:]
test=data[row:,:]

#shuffle the training data
np.random.shuffle(train)
#format traning data nad testing data
train_y=train[:,[0]]
train_x=train[:,[1,2,3]]  
test_y=test[:,[0]]
test_x=test[:,[1,2,3]]
model3 = Sequential()
model3.add(Dense(64, input_dim=3, kernel_initializer='normal', activation='relu'))


model3.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))

start = time.time()
sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0, nesterov=False)
model3.compile(loss='mse', optimizer='adam')
print ('compilation time : ', time.time() - start)



model3.fit(
    train_x,
    train_y,
    batch_size=32,
    nb_epoch=1000,
    validation_split=0.05)

predictions = lstm.predict_point_by_point(model3, test_x)
plot_results(predictions,test_y)
from sklearn.metrics import r2_score
r2_score(test_y, predictions)
# Out:
# compilation time :  0.051011085510253906
# Train on 1509 samples, validate on 80 samples
# Epoch 1/1000
# 1509/1509 [==============================] - 0s - loss: 0.0436 - val_loss: 0.0233
# Epoch 2/1000
# 1509/1509 [==============================] - 0s - loss: 0.0196 - val_loss: 0.0148
# Epoch 3/1000
# 1509/1509 [==============================] - 0s - loss: 0.0150 - val_loss: 0.0147
# Epoch 4/1000
# 1509/1509 [==============================] - 0s - loss: 0.0144 - val_loss: 0.0143
# Epoch 5/1000
# 1509/1509 [==============================] - 0s - loss: 0.0139 - val_loss: 0.0136
# Epoch 6/1000
# 1509/1509 [==============================] - 0s - loss: 0.0132 - val_loss: 0.0127
# Epoch 7/1000
# 1509/1509 [==============================] - 0s - loss: 0.0125 - val_loss: 0.0119
# Epoch 8/1000
# 1509/1509 [==============================] - 0s - loss: 0.0117 - val_loss: 0.0112
# Epoch 9/1000
# 1509/1509 [==============================] - 0s - loss: 0.0107 - val_loss: 0.0101
# Epoch 10/1000
# ...
